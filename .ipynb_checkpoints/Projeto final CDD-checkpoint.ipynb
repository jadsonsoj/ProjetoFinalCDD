# %% [markdown]
# <h1> Projeto Final - Ciência dos Dados <h1>
# <h2> Integrantes: <li> Luigi Portugal
#                   <li> Jadson Silva

# %% [markdown]
# <h2> Dataset escolhido: FIFA 18 Players<h2>
# <h3> Problematização: Com base nos parâmetros do dataset referentes a atributos de jogadores de futebol, seria possível criar um algoritmo que os agrupasse conforme suas posições em campo?<h3>

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import math 
from scipy import stats

# %%
dataset = pd.read('CompleteDataset.csv')
dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-298ada6881c2> in <module>()
# ----> 1 dataset = pd.read('CompleteDataset.csv')
#       2 dataset
#
# AttributeError: module 'pandas' has no attribute 'read'
